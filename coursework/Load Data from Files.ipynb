# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Load Data from Files.ipynb',
#  'supermarkets.csv.xlsx',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'supermarkets_commas.txt',
#  'supermarkets_semi-colons.txt']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
#can have parameter of header=None
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees  Unnamed: 7
# ID
# 1           8         NaN
# 2          15         NaN
# 3          25         NaN
# 4          10         NaN
# 5          12         NaN
# 6          20         NaN

# %%
df1.shape
# Out:
# (6, 8)

# %%
df2=pandas.read_json("supermarkets.json")
df2.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4=pandas.read_csv("supermarkets_commas.txt")
#can pass separator parameter if commas not used
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets_semi-colons.txt",sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pandas.read_csv?

# %%
df6=pandas.read_csv("http://pythonhow.com/supermarkets.csv")
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7=pandas.read_json("http://pythonhow.com/supermarkets.json")
df7
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7=df7.set_index("Address")

# %%
df7.loc["735 Dolores St":"332 Hill St","State":"Country"]
# Out:
#                            State Country
# Address
# 735 Dolores St          CA 94119     USA
# 332 Hill St     California 94114     USA

# %%
df7.loc[:,"State":"Country"]
# Out:
#                             State Country
# Address
# 3666 21st St             CA 94114     USA
# 735 Dolores St           CA 94119     USA
# 332 Hill St      California 94114     USA
# 3995 23rd St             CA 94114     USA
# 1056 Sanchez St        California     USA
# 551 Alvarado St          CA 94114     USA

# %%
df7.set_index?
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.iloc[1:4,1:4]
#upper bound exclusive
# Out:
#                          City             State Country
# Address
# 735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St     San Francisco  California 94114     USA
# 3995 23rd St    San Francisco          CA 94114     USA

# %%
df7.iloc[:,1:4]
# Out:
#                           City             State Country
# Address
# 3666 21st St     San Francisco          CA 94114     USA
# 735 Dolores St   San Francisco          CA 94119     USA
# 332 Hill St      San Francisco  California 94114     USA
# 3995 23rd St     San Francisco          CA 94114     USA
# 1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  San Francisco          CA 94114     USA

# %%
df7.iloc[3,1:4]
# Out:
# City       San Francisco
# State           CA 94114
# Country              USA
# Name: 3995 23rd St, dtype: object

# %%
#df7.ix[3,"Name"]
#ix no longer used

# %%
df7?

# %%
df7.drop("City",1)
#1 is to delet columns, 0 is rows
# Out:
#                  ID             State Country         Name  Employees
# Address
# 3666 21st St      1          CA 94114     USA      Madeira          8
# 735 Dolores St    2          CA 94119     USA  Bready Shop         15
# 332 Hill St       3  California 94114     USA  Super River         25
# 3995 23rd St      4          CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5        California     USA      Sanchez         12
# 551 Alvarado St   6          CA 94114     USA   Richvalley         20

# %%
df7.drop("332 Hill St",0)
# Out:
#                  ID           City       State Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7.drop(df7.index[0:3], 0)
# Out:
#                  ID           City       State Country        Name  Employees
# Address
# 3995 23rd St      4  San Francisco    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA  Richvalley         20

# %%
df7.drop(df7.columns[0:3],1)
# Out:
#                 Country         Name  Employees
# Address
# 3666 21st St        USA      Madeira          8
# 735 Dolores St      USA  Bready Shop         15
# 332 Hill St         USA  Super River         25
# 3995 23rd St        USA   Ben's Shop         10
# 1056 Sanchez St     USA      Sanchez         12
# 551 Alvarado St     USA   Richvalley         20

# %%
len(df7.index)
# Out:
# 6

# %%
df7["Continent"]=df7.shape[0]*["North America"]
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees      continent      Continent
# Address
# 3666 21st St             8  North America  North America
# 735 Dolores St          15  North America  North America
# 332 Hill St             25  North America  North America
# 3995 23rd St            10  North America  North America
# 1056 Sanchez St         12  North America  North America
# 551 Alvarado St         20  North America  North America

# %%
df7=df7.drop("continent", 1)

# %%
df7["Continent"]=df7["Country"] + ", " + "North America"
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees           Continent
# Address
# 3666 21st St             8  USA, North America
# 735 Dolores St          15  USA, North America
# 332 Hill St             25  USA, North America
# 3995 23rd St            10  USA, North America
# 1056 Sanchez St         12  USA, North America
# 551 Alvarado St         20  USA, North America

# %%
df7_t=df7.T

# %%
df7_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# ID                          1                   2                   3
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# ID                          4                   5                   6
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df7_t["My Address"]=["My City","My Country",10,7,"My Shop","My State","My Continent"]

# %%
df7_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# ID                          1                   2                   3
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St  \
# ID                          4                   5                   6
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df7=df7_t.T
df7
# Out:
#                       ID           City             State Country  \
# Address
# 3666 21st St           1  San Francisco          CA 94114     USA
# 735 Dolores St         2  San Francisco          CA 94119     USA
# 332 Hill St            3  San Francisco  California 94114     USA
# 3995 23rd St           4  San Francisco          CA 94114     USA
# 1056 Sanchez St        5  San Francisco        California     USA
# 551 Alvarado St        6  San Francisco          CA 94114     USA
# My Address       My City     My Country                10       7
#
#                         Name Employees           Continent
# Address
# 3666 21st St         Madeira         8  USA, North America
# 735 Dolores St   Bready Shop        15  USA, North America
# 332 Hill St      Super River        25  USA, North America
# 3995 23rd St      Ben's Shop        10  USA, North America
# 1056 Sanchez St      Sanchez        12  USA, North America
# 551 Alvarado St   Richvalley        20  USA, North America
# ...

# %%
dm=pandas.merge(left=df6,right=df7,on="ID")

# %%
dm
# Out:
#   ID          Address         City_x           State_x Country_x       Name_x  \
# 0  1     3666 21st St  San Francisco          CA 94114       USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119       USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114       USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114       USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California       USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114       USA   Richvalley
#
#    Employees_x         City_y           State_y Country_y       Name_y  \
# 0            8  San Francisco          CA 94114       USA      Madeira
# 1           15  San Francisco          CA 94119       USA  Bready Shop
# 2           25  San Francisco  California 94114       USA  Super River
# 3           10  San Francisco          CA 94114       USA   Ben's Shop
# ...

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import Nominatim

# %%
nom=Nominatim(user_agent="Bjcurty@gmail.com")

# %%
n1 = nom.geocode("1191 Ada Ave, Idaho Falls, ID 83402")
print(n1.latitude, n1.longitude)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b9d0a7cf2a44> in <module>
# ----> 1 n1 = nom.geocode("1191 Ada Ave, Idaho Falls, ID 83402")
#       2 print(n1.latitude, n1.longitude)
#
# NameError: name 'nom' is not defined

# %%
print(n1.address)
# Out:
# 121, Clubhouse Circle, Idaho Falls, Bonneville County, Idaho, 83401, United States of America

# %%
df=pandas.read_csv("supermarkets.csv")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Unnamed: 7
# 0          8         NaN
# 1         15         NaN
# 2         25         NaN
# 3         10         NaN
# 4         12         NaN
# 5         20         NaN

# %%
df["Address"]=df["Address"]+", "+df["City"]+", "+df["Country"]
df
# Out:
#    ID                              Address           City             State  \
# 0   1     3666 21st St, San Francisco, USA  San Francisco          CA 94114
# 1   2   735 Dolores St, San Francisco, USA  San Francisco          CA 94119
# 2   3      332 Hill St, San Francisco, USA  San Francisco  California 94114
# 3   4     3995 23rd St, San Francisco, USA  San Francisco          CA 94114
# 4   5  1056 Sanchez St, San Francisco, USA  San Francisco        California
# 5   6  551 Alvarado St, San Francisco, USA  San Francisco          CA 94114
#
#   Country         Name  Employees  Unnamed: 7
# 0     USA      Madeira          8         NaN
# 1     USA  Bready Shop         15         NaN
# 2     USA  Super River         25         NaN
# 3     USA   Ben's Shop         10         NaN
# 4     USA      Sanchez         12         NaN
# 5     USA   Richvalley         20         NaN

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df.Coordinates
# Out:
# 0    (3666, 21st Street, Noe Valley, San Francisco,...
# 1    (735, Dolores Street, Liberty Street Historic ...
# 2    (332, Hill Street, Noe Valley, San Francisco, ...
# 3    (3995, 23rd Street, Noe Valley, San Francisco,...
# 4    (1056, Sanchez Street, Noe Valley, San Francis...
# 5    (551, Alvarado Street, Noe Valley, San Francis...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0]
# Out:
# Location(3666, 21st Street, Noe Valley, San Francisco, San Francisco City and County, California, 94114, United States of America, (37.75648887755102, -122.42934334693878, 0.0))

# %%
df.Coordinates[0].latitude
df.Coordinates[0].longitude
# Out:
# -122.42934334693878

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df
# Out:
#    ID                              Address           City             State  \
# 0   1     3666 21st St, San Francisco, USA  San Francisco          CA 94114
# 1   2   735 Dolores St, San Francisco, USA  San Francisco          CA 94119
# 2   3      332 Hill St, San Francisco, USA  San Francisco  California 94114
# 3   4     3995 23rd St, San Francisco, USA  San Francisco          CA 94114
# 4   5  1056 Sanchez St, San Francisco, USA  San Francisco        California
# 5   6  551 Alvarado St, San Francisco, USA  San Francisco          CA 94114
#
#   Country         Name  Employees  Unnamed: 7  \
# 0     USA      Madeira          8         NaN
# 1     USA  Bready Shop         15         NaN
# 2     USA  Super River         25         NaN
# 3     USA   Ben's Shop         10         NaN
# 4     USA      Sanchez         12         NaN
# 5     USA   Richvalley         20         NaN
#
#                                          Coordinates   Latitude
# ...

# %%
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df
# Out:
#    ID                              Address           City             State  \
# 0   1     3666 21st St, San Francisco, USA  San Francisco          CA 94114
# 1   2   735 Dolores St, San Francisco, USA  San Francisco          CA 94119
# 2   3      332 Hill St, San Francisco, USA  San Francisco  California 94114
# 3   4     3995 23rd St, San Francisco, USA  San Francisco          CA 94114
# 4   5  1056 Sanchez St, San Francisco, USA  San Francisco        California
# 5   6  551 Alvarado St, San Francisco, USA  San Francisco          CA 94114
#
#   Country         Name  Employees  Unnamed: 7  \
# 0     USA      Madeira          8         NaN
# 1     USA  Bready Shop         15         NaN
# 2     USA  Super River         25         NaN
# 3     USA   Ben's Shop         10         NaN
# 4     USA      Sanchez         12         NaN
# 5     USA   Richvalley         20         NaN
#
#                                          Coordinates   Latitude   Longitude
# ...
